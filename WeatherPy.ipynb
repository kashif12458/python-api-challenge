# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %%
import requests

API_KEY = "db1bdd261502ea08da03d8a88cc76798"
cities = cities # Replace with your own city list

def get_weather_data(city):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}"
    response = requests.get(url)
    data = response.json()
    return data

for city in cities:
    try:
        weather_data = get_weather_data(city)
        
        # Extracting desired details
        longitude = weather_data['coord']['lon']
        latitude = weather_data['coord']['lat']
        temperature = weather_data['main']['temp']
        humidity = weather_data['main']['humidity']
        wind_speed = weather_data['wind']['speed']
        cloud_coverage = weather_data['clouds']['all']
        
        # Printing the details
        print(f"Weather in {city}:")
        print(f"Longitude: {longitude}")
        print(f"Latitude: {latitude}")
        print(f"Temperature: {temperature}°C")
        print(f"Humidity: {humidity}%")
        print(f"Wind Speed: {wind_speed} m/s")
        print(f"Cloud Coverage: {cloud_coverage}%")
        print("")
        
    except KeyError as e:
        print(f"Error retrieving weather data for {city}. KeyError: {e}")
        print("")
    except Exception as e:
        print(f"Error retrieving weather data for {city}. Exception: {e}")
        print("")
# Out:
# Weather in shingu:
# Longitude: 135.9833
# Latitude: 33.7333
# Temperature: 297.27°C
# Humidity: 81%
# Wind Speed: 2.45 m/s
# Cloud Coverage: 0%
#
# Weather in bethel:
# Longitude: -73.414
# Latitude: 41.3712
# Temperature: 303.4°C
# Humidity: 60%
# Wind Speed: 2.57 m/s
# Cloud Coverage: 0%
#
# Weather in sussex:
# Longitude: -74.6663
# Latitude: 41.1834
# Temperature: 302.24°C
# Humidity: 54%
# Wind Speed: 2.57 m/s
# Cloud Coverage: 0%
#
# Weather in puerto natales:
# Longitude: -72.4875
# Latitude: -51.7236
# Temperature: 279.4°C
# Humidity: 52%
# Wind Speed: 8.23 m/s
# Cloud Coverage: 40%
#
# Weather in thompson:
# Longitude: -97.8558
# Latitude: 55.7435
# Temperature: 292.24°C
# Humidity: 63%
# Wind Speed: 4.63 m/s
# Cloud Coverage: 75%
#
# Weather in zabaykal'sk:
# Longitude: 117.3167
# Latitude: 49.6333
# Temperature: 293.84°C
# Humidity: 57%
# Wind Speed: 4.07 m/s
# Cloud Coverage: 100%
#
# Weather in olonkinbyen:
# Longitude: -8.7187
# Latitude: 70.9221
# ...

# %%
import requests
import pandas as pd

API_KEY = "db1bdd261502ea08da03d8a88cc76798"
cities = cities # Replace with your own city list

def get_weather_data(city):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
    response = requests.get(url)
    data = response.json()
    return data

weather_data_list = []

for city in cities:
    try:
        weather_data = get_weather_data(city)
        
        # Extracting desired details
        longitude = weather_data['coord']['lon']
        latitude = weather_data['coord']['lat']
        temperature = weather_data['main']['temp']
        humidity = weather_data['main']['humidity']
        wind_speed = weather_data['wind']['speed']
        cloud_coverage = weather_data['clouds']['all']
        country = weather_data['sys']['country']
        date = weather_data['dt']
        
        # Create a dictionary with the weather details
        weather_data_dict = {
            'City': city,
            'Longitude': longitude,
            'Latitude': latitude,
            'Temperature': temperature,
            'Humidity': humidity,
            'Wind Speed': wind_speed,
            'Cloud Coverage': cloud_coverage,
            'Country': country,
            'Date': date
        }
        
        # Append the dictionary to the list
        weather_data_list.append(weather_data_dict)
        
    except KeyError as e:
        print(f"Error retrieving weather data for {city}. KeyError: {e}")
        print("")
    except Exception as e:
        print(f"Error retrieving weather data for {city}. Exception: {e}")
        print("")

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(weather_data_list)

# Save the DataFrame to a CSV file
df.to_csv('weather_data.csv', index=False)

print("DataFrame saved to 'weather_data.csv'")
# Out:
# Error retrieving weather data for taiohae. KeyError: 'coord'
#
# Error retrieving weather data for cargados carajos. KeyError: 'coord'
#
# Error retrieving weather data for kataragama. KeyError: 'coord'
#
# Error retrieving weather data for olgii. KeyError: 'coord'
#
# Error retrieving weather data for espargos. KeyError: 'coord'
#
# Error retrieving weather data for hihifo. KeyError: 'coord'
#
# Error retrieving weather data for puerto san carlos. KeyError: 'coord'
#
# Error retrieving weather data for karosta. KeyError: 'coord'
#
# Error retrieving weather data for 'ohonua. KeyError: 'coord'
#
# Error retrieving weather data for ouellah. KeyError: 'coord'
#
# Error retrieving weather data for bejubang dua. KeyError: 'coord'
#
# Error retrieving weather data for velky krtis. KeyError: 'coord'
#
# Error retrieving weather data for koneurgench. KeyError: 'coord'
#
# Error retrieving weather data for pont-l'abbe. KeyError: 'coord'
#
# ...

# %%
df.count()
# Out:
# City              579
# Longitude         579
# Latitude          579
# Temperature       579
# Humidity          579
# Wind Speed        579
# Cloud Coverage    579
# Country           579
# Date              579
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | farsund
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | lanzhou
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | colorado
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | trairi
# Processing Record 15 of Set 1 | dobryanka
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | puerto ayora
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
df.head()
# Out:
#                 City  Longitude  Latitude  Temperature  Humidity  Wind Speed  \
# 0  port-aux-francais    70.2167  -49.3500         6.53        87       16.05
# 1            talnakh    88.3972   69.4865        12.87        86        5.86
# 2            bodaybo   114.1933   57.8506        14.63        74        1.20
# 3            chonchi   -73.8092  -42.6128         2.29        83        1.57
# 4            markala    -6.0659   13.7021        36.04        34        2.92
#
#    Cloud Coverage Country        Date
# 0              99      TF  1689686393
# 1             100      RU  1689686343
# 2             100      RU  1689686394
# 3             100      CL  1689686394
# 4              93      ML  1689686395

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather data from CSV
df = pd.read_csv('weather_data.csv')

# Extract latitude and temperature from the DataFrame
latitude = df['Latitude']
temperature = df['Temperature']

# Plotting the scatter plot
plt.scatter(latitude, temperature, color='blue', edgecolor='black', alpha=0.7)

# Adding labels and title
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.title('Latitude vs. Temperature')


# Incorporate the other graph properties
plt.grid(True)  # Add grid lines



# Save the figure
plt.savefig("C:/Users/Khawja Mujtaba/Untitled Folder/Starter_Code/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = df['Latitude']
humidity = df['Humidity']


plt.scatter(latitude, humidity, color='blue', edgecolor='black', alpha=0.7)

# Adding labels and title
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity')

# Customizing the plot
plt.grid(True)  # Add grid lines


# Save the figure
plt.savefig("C:/Users/Khawja Mujtaba/Untitled Folder/Starter_Code/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather data from CSV
df = pd.read_csv('weather_data.csv')

# Extract latitude and cloudiness from the DataFrame
latitude = df['Latitude']
cloudiness = df['Cloud Coverage']

# Plotting the scatter plot
plt.scatter(latitude, cloudiness, color='blue', edgecolor='black', alpha=0.7)

# Adding labels and title
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs. Cloudiness')

# Customizing the plot
plt.grid(True)  # Add grid lines


# Save the figure
plt.savefig("C:/Users/Khawja Mujtaba/Untitled Folder/Starter_Code/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitude = df['Latitude']
wind_speed = df['Wind Speed']

# Plotting the scatter plot
plt.scatter(latitude, wind_speed, color='blue', edgecolor='black', alpha=0.7)

# Adding labels and title
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Latitude vs. Wind Speed')

# Customizing the plot
plt.grid(True)  # Add grid lines


# Save the figure
plt.savefig("C:/Users/Khawja Mujtaba/Untitled Folder/Starter_Code/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

def create_linear_regression_scatter(x, y, hemisphere):
    # Extract data based on the hemisphere
    if hemisphere == 'Northern':
        filtered_x = x[x >= 0]
        filtered_y = y[x >= 0]
    elif hemisphere == 'Southern':
        filtered_x = x[x < 0]
        filtered_y = y[x < 0]
    else:
        raise ValueError("Invalid hemisphere. Must be 'Northern' or 'Southern'.")

    # Plotting the scatter plot
    plt.scatter(filtered_x, filtered_y, color='blue', alpha=0.7)

    # Adding labels and title
    plt.xlabel('Latitude')
    plt.ylabel('Y-axis')
    plt.title(f'{hemisphere} Hemisphere: Y-axis vs. Latitude')

    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(filtered_x, filtered_y)
    line = slope * filtered_x + intercept

    # Plot the regression line
    plt.plot(filtered_x, line, color='red', linewidth=2)

    # Add equation and R-value to the plot
    equation = f"y = {slope:.2f}x + {intercept:.2f}"
    r_value_text = f"R = {r_value:.2f}"
    plt.text(0.05, 0.85, equation, transform=plt.gca().transAxes, fontsize=12)
    plt.text(0.05, 0.78, r_value_text, transform=plt.gca().transAxes, fontsize=12)

    # Display the plot
    plt.show()

# %%
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
df = pd.read_csv('weather_data.csv')
create_linear_regression_scatter(df['Latitude'], df['Temperature'], 'Northern')

# %%
# Linear regression on Southern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Temperature'], 'Southern')

# %% [markdown]
# **Discussion about the linear relationship:** considering northern hemisphere we see an over all decreasing trend of temperature as latitude increases however the linear relation is not that strong a r=-0.54 and we can see as the data is spread we will see more residuals. However, in southern hemisphere data is less spread and r value =0.85, thus we can  see strong linear assosiation between latitude and temperature. As the lattitude increases the temperature increases

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Humidity'], 'Northern')

# %%
# Southern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Humidity'], 'Southern')

# %% [markdown]
# **Discussion about the linear relationship:** The assosiation between humidity and latitude is fairly the same in northern and southern hemisphere, as we can see in both the hemispheres that data is scattered and r value of both the linear models is close to zero, thus it seems there is no linear assosiation between humidity and latitude

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Cloud Coverage'], 'Northern')

# %%
# Southern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Cloud Coverage'], 'Southern')

# %% [markdown]
# **Discussion about the linear relationship:** The assosiation between cloudiness and latitude is fairly the same in northern and southern hemisphere, as we can see in both the hemispheres that data is scattered and r value of both the linear models is close to zero, thus it seems there is no linear assosiation between humidity and latitude. The relationship pretty much seems similar to humidity and lattitude, as it might be possible cloudness and humidity is linked

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Wind Speed'], 'Northern')

# %%
# Southern Hemisphere
create_linear_regression_scatter(df['Latitude'], df['Wind Speed'], 'Southern')

# %% [markdown]
# **Discussion about the linear relationship:** While considering wind and lattitude linear assosciation in northern and southern hemispheres, we can see there no linear assosciation in northern hemisphere as r= 0.02 and in southern the relation ship is super week as r =-0.15
